# %% [markdown]
# <a href="https://colab.research.google.com/github/Christina-178/DTS101_assignment-/blob/main/WEEK_5_File_Handling_and_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WEEK 5: File Handling and CSV Data Processing
#
# **Programme:** Data Science
# **Course Title:** Data Visualization and Storytelling (Practical)
# **Week:** 5
# **Contact Hours:** 2 Hours Lecture + 2 Hours Practical
#
# ---
#
# ## Course Overview
#
# This week introduces File Handling in Python.
#
# Students will learn how to:
#
# - Open files using open()
# - Read CSV files
# - Extract specific data columns
# - Process numerical values
# - Compute averages from file data
# - Apply algorithms to real datasets

# %% [markdown]
# ## Learning Outcomes
#
# By the end of this week, students should be able to:
#
# - Explain how file handling works in Python
# - Read and process CSV files
# - Compute statistical summaries from file data
# - Apply loops and conditions to file content

# %% [markdown]
# # PART 1: Opening and Reading a File

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-d5ac36ab-9668-4830-b24e-66ed92f35abe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d5ac36ab-9668-4830-b24e-66ed92f35abe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open("week5_student_scores (1).csv", "r") as file:
    for line in file:
        print(line)
# Out:
# student_id,name,math,english,science
#
# S001,Alice,65,70,72
#
# S002,Bob,80,85,78
#
# S003,Charlie,45,50,48
#
# S004,David,90,88,92
#
# S005,Eva,75,80,79

# %%
file = open("week5_student_scores (1).csv", "r")

for line in file:
    print(line)

file.close()
# Out:
# student_id,name,math,english,science
#
# S001,Alice,65,70,72
#
# S002,Bob,80,85,78
#
# S003,Charlie,45,50,48
#
# S004,David,90,88,92
#
# S005,Eva,75,80,79

# %% [markdown]
# Explanation:
#
# - open(filename, "r") opens file in read mode
# - for loop reads each line
# - close() releases system resources

# %% [markdown]
# # PART 2: Extracting Specific Columns

# %%
file = open("week5_student_scores (1).csv", "r")

next(file)  # Skip header row

for line in file:
    data = line.strip().split(",")

    student_id = data[0]
    name = data[1]
    math_score = int(data[2])

    print(student_id, name, math_score)

file.close()
# Out:
# S001 Alice 65
# S002 Bob 80
# S003 Charlie 45
# S004 David 90
# S005 Eva 75

# %% [markdown]
# # PART 3: Compute Average Math Score

# %%
file = open("week5_student_scores (1).csv", "r")

next(file)

total = 0
count = 0

for line in file:
    data = line.strip().split(",")
    math_score = int(data[2])

    total += math_score
    count += 1

average = total / count

print("Average Math Score:", average)

file.close()
# Out:
# Average Math Score: 71.0

# %% [markdown]
# # PART 4: Store Scores in a List

# %%
scores = []

file = open("week5_student_scores (1).csv", "r")
next(file)

for line in file:
    data = line.strip().split(",")
    scores.append(int(data[2]))

file.close()

print("Math Scores:", scores)
# Out:
# Math Scores: [65, 80, 45, 90, 75]

# %% [markdown]
# # PART 5: Find Highest and Lowest Scores

# %%
highest = scores[0]
lowest = scores[0]

for score in scores:
    if score > highest:
        highest = score

    if score < lowest:
        lowest = score

print("Highest Math Score:", highest)
print("Lowest Math Score:", lowest)
# Out:
# Highest Math Score: 90
# Lowest Math Score: 45

# %% [markdown]
# # PRACTICAL EXERCISE
#
# 1. Read the file and print student names only.
# 2. Compute average English score.
# 3. Compute average Science score.
# 4. Find lowest Science score.

# %% [markdown]
# #Practical exercise 1
# Read file and print student names

# %%
file = open("week5_student_scores (1).csv", "r")

next(file)  # Skip header row

for line in file:
    data = line.strip().split(",")

    name = data[1]

    print(name)

file.close()
# Out:
# Alice
# Bob
# Charlie
# David
# Eva

# %% [markdown]
# #Practical exercise 2
# Compute Average english score

# %%
file = open("week5_student_scores (1).csv", "r")

next(file)

total = 0
count = 0

for line in file:
    data = line.strip().split(",")
    english_score = int(data[3])

    total += english_score
    count += 1

average = total / count

print("Average English Score:", average)

file.close()
# Out:
# Average English Score: 74.6

# %% [markdown]
# #Practical exercise 3
# Compute Average Science score

# %%
file = open("week5_student_scores (1).csv", "r")

next(file)

total = 0
count = 0

for line in file:
    data = line.strip().split(",")
    science_score = int(data[4])

    total += science_score
    count += 1

average = total / count

print("Average Science Score:", average)

file.close()
# Out:
# Average Science Score: 73.8

# %% [markdown]
# #Practical exercise 4
# Find the lowest science score

# %%
lowest = float('inf')

with open("week5_student_scores (1).csv", "r") as file:
    next(file)

    for line in file:
        data = line.strip().split(",")
        science_score = int(data[4])

        if science_score < lowest:
            lowest = science_score

print("Lowest Science Score:", lowest)
# Out:
# Lowest Science Score: 48

# %% [markdown]
# # ASSIGNMENT (Week 5)
#
# 1. Read the CSV file.
# 2. Compute:
#    - Average Math score
#    - Average English score
#    - Average Science score
# 3. Find:
#    - Highest overall score
#    - Lowest overall score
# 4. Print all results clearly.
#
# Submit your completed notebook (.ipynb)

# %% [markdown]
# #1. Read the CSV file

# %%
file = open('week5_student_scores (1).csv', 'r')

for line in file:
  print(line)

file.close()
# Out:
# student_id,name,math,english,science
#
# S001,Alice,65,70,72
#
# S002,Bob,80,85,78
#
# S003,Charlie,45,50,48
#
# S004,David,90,88,92
#
# S005,Eva,75,80,79

# %% [markdown]
# #2. Compute:
# a.Average Math Score
#
# b.Average English Score
#
# c.Average Science score

# %%
file = open("week5_student_scores (1).csv", "r")

next(file)

total = 0
count = 0

for line in file:
    data = line.strip().split(",")
    math_score = int(data[2])

    total += math_score
    count += 1

average_math= total / count

print("Average Math Score:", average_math)

file.close()
# Out:
# Average Math Score: 71.0

# %%
file = open("week5_student_scores (1).csv", "r")

next(file)

total = 0
count = 0

for line in file:
    data = line.strip().split(",")
    english_score = int(data[3])

    total += english_score
    count += 1

average_english = total / count

print("Average English Score:", average_english)

file.close()
# Out:
# Average English Score: 74.6

# %%
file = open("week5_student_scores (1).csv", "r")

next(file)

total = 0
count = 0

for line in file:
    data = line.strip().split(",")
    science_score = int(data[4])

    total += science_score
    count += 1

average_science = total / count

print("Average Science Score:", average_science)

file.close()
# Out:
# Average Science Score: 73.8

# %% [markdown]
# #Find
# a.Highest overall score
# b.Lowest overall score

# %%
highest = scores[0]
lowest = scores[0]

for score in scores:
    if score > highest:
        highest = score

    if score < lowest:
        lowest = score

print("Highest Overall Score:", highest)
print("Lowest Overall Score:", lowest)
# Out:
# Highest Overall Score: 90
# Lowest Overall Score: 45

# %% [markdown]
# #4. Print result

# %%
print("week5_student_scores (1).csv" "r")

# Print averages
print("Average Math score   :", average_math)
print("Average English score:", average_english)
print("Average Science score:", average_english)

# Print highest and lowest
print("Highest Overall score:", highest)
print("Lowest Overall score :", lowest)

file.close()
# Out:
# week5_student_scores (1).csvr
# Average Math score   : 71.0
# Average English score: 74.6
# Average Science score: 74.6
# Highest Overall score: 90
# Lowest Overall score : 45
